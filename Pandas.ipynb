# %%
import pandas as pd

# %%
df=pd.read_csv('Book1.csv')
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
temp_dict={'col1':[1,2,3],'col2':[4,5,6],'col3':[7,8,9]}
dictdf=pd.DataFrame.from_dict(temp_dict)

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# ...

# %%
df.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2             77.0
# 3329                      0              231.1             57.0
# 3330                      0              180.8            109.0
# 3331                      0              213.8            105.0
# 3332                     25              234.4            113.0
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
dictdf.head()
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls           float64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls           float64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls         float64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls    float64
# Churn                      object
# dtype: object

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3323.000000
# mean       101.064806   437.182418               8.099010         179.787150
# std         39.822106    42.371290              13.688365          54.419625
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.500000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3323.000000       3315.000000        3324.000000      3325.000000
# mean        100.456214         30.557831         201.033935       100.110677
# ...

# %%
df.describe(include='object')
# Out:
#        State International plan Voice mail plan  Churn
# count   3333               3333            3333   3325
# unique    51                  2               2      2
# top       WV                 No              No  False
# freq     106               3010            2411   2842

# %%
df[['International plan','State']]
# Out:
#      International plan State
# 0                    No    KS
# 1                    No    OH
# 2                    No    NJ
# 3                   Yes    OH
# 4                   Yes    OK
# ...                 ...   ...
# 3328                 No    AZ
# 3329                 No    WV
# 3330                 No    RI
# 3331                Yes    CT
# 3332                 No    TN
#
# [3333 rows x 2 columns]

# %%
df.State.unique()
# Out:
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'LA', 'WV', 'IN', 'RI',
#        'IA', 'MT', 'NY', 'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'SC',
#        'NE', 'WY', 'HI', 'IL', 'NH', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR',
#        'MI', 'DE', 'UT', 'CA', 'MN', 'SD', 'NC', 'WA', 'NM', 'NV', 'DC',
#        'KY', 'ME', 'MS', 'TN', 'PA', 'CT', 'ND'], dtype=object)

# %%
df[df.State=='KS']
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 179     KS              70        408                 No              No
# 258     KS              92        408                Yes              No
# 287     KS             137        408                 No              No
# 368     KS             132        415                 No              No
# ...    ...             ...        ...                ...             ...
# 3217    KS             164        510                 No             Yes
# 3244    KS             101        415                 No              No
# 3253    KS             127        415                 No             Yes
# 3285    KS              57        415                 No              No
# 3287    KS             170        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df[(df.State=='KS')&(df['International plan']=='No')]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 179     KS              70        408                 No              No
# 287     KS             137        408                 No              No
# 368     KS             132        415                 No              No
# 379     KS             127        415                 No              No
# ...    ...             ...        ...                ...             ...
# 3217    KS             164        510                 No             Yes
# 3244    KS             101        415                 No              No
# 3253    KS             127        415                 No             Yes
# 3285    KS              57        415                 No              No
# 3287    KS             170        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.iloc[14]
# Out:
# State                        IA
# Account length               62
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes           NaN
# Total day calls             NaN
# Total day charge            NaN
# Total eve minutes         307.2
# Total eve calls              76
# Total eve charge          26.11
# Total night minutes         203
# Total night calls            99
# Total night charge         9.14
# Total intl minutes         13.1
# Total intl calls              6
# Total intl charge          3.54
# Customer service calls        4
# Churn                     False
# Name: 14, dtype: object

# %%
df.iloc[14,0]
# Out:
# 'IA'

# %%
df.iloc[20:40]
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 20    FL             147        415                 No              No
# 21    CO              77        408                 No              No
# 22    AZ             130        415                 No              No
# 23    SC             111        415                 No              No
# 24    VA             132        510                 No              No
# 25    NE             174        415                 No              No
# 26    WY              57        408                 No             Yes
# 27    MT              54        408                 No              No
# 28    MO              20        415                 No              No
# 29    HI              49        510                 No              No
# 30    IL             142        415                 No              No
# 31    NH              75        510                 No              No
# ...

# %%
df.set_index('State',inplace=True)
df.loc['OH']
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# OH                107        415                 No             Yes
# OH                 84        408                Yes              No
# OH                 65        408                 No              No
# OH                 83        415                 No              No
# OH                 63        415                Yes             Yes
# ...               ...        ...                ...             ...
# OH                160        415                 No              No
# OH                 88        408                 No              No
# OH                106        415                 No             Yes
# OH                 78        408                 No              No
# OH                 96        415                 No              No
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# OH                        26              161.6            123.0
# ...

# %%
df.isnull().sum()
# Out:
# Account length             0
# Area code                  0
# International plan         0
# Voice mail plan            0
# Number vmail messages      0
# Total day minutes         10
# Total day calls           10
# Total day charge          18
# Total eve minutes          9
# Total eve calls            8
# Total eve charge           0
# Total night minutes        0
# Total night calls          1
# Total night charge         0
# Total intl minutes         0
# Total intl calls           0
# Total intl charge          5
# Customer service calls     5
# Churn                      8
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
df.drop('Total day charge',axis=1)
df.shape
# Out:
# (3307, 19)

# %%
df['new column']=df['Total day calls'] + df['Total eve calls']+ df['Total night calls']
df['new column']
# Out:
# State
# KS    300.0
# OH    329.0
# NJ    328.0
# OH    248.0
# OK    356.0
#       ...
# AZ    286.0
# WV    235.0
# RI    258.0
# CT    326.0
# TN    272.0
# Name: new column, Length: 3307, dtype: float64

# %%
df['Churn binary']=df['Churn'].apply(lambda x: 1 if x== True else 0)
df[['Churn','Churn binary']]
# Out:
#        Churn  Churn binary
# State
# KS     False             0
# OH     False             0
# NJ     False             0
# OH     False             0
# OK     False             0
# AL     False             0
# MO     False             0
# LA     False             0
# WV     False             0
# IN      True             1
# RI     False             0
# SC     False             0
# VA     False             0
# NE     False             0
# WY     False             0
# MT     False             0
# MO     False             0
# IL     False             0
# NJ     False             0
# GA     False             0

# %%
df.to_csv('output.csv')
